# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_base = pd.read_excel('/Users/saeed/Dropbox/Sharif Business Think Thank/خصوصی سازی/شرکت‌های مورد بررسی.xlsx',
                        sheet_name="treatment")

# %%
df_base.head(20)
# Out:
#     ردیف                   نام شرکت نام نماد  سال آخرین صورت مالی  \
# 0    1.0  آلومینیوم ایران (ایرالکو)    فایرا                 1399
# 1    NaN  آلومینیوم ایران (ایرالکو)    فایرا                 1398
# 2    NaN  آلومینیوم ایران (ایرالکو)    فایرا                 1397
# 3    NaN  آلومینیوم ایران (ایرالکو)    فایرا                 1396
# 4    2.0           پالایش نفت تبریز    شبریز                 1399
# 5    NaN           پالایش نفت تبریز    شبریز                 1398
# 6    NaN           پالایش نفت تبریز    شبریز                 1397
# 7    NaN           پالایش نفت تبریز    شبریز                 1396
# 8    3.0           پالایش نفت شیراز     شراز                 1399
# 9    NaN           پالایش نفت شیراز     شراز                 1398
# 10   NaN           پالایش نفت شیراز     شراز                 1397
# 11   NaN           پالایش نفت شیراز     شراز                 1396
# 12   4.0            پتروشیمی خراسان   خراسان                 1399
# 13   NaN            پتروشیمی خراسان   خراسان                 1398
# 14   NaN            پتروشیمی خراسان   خراسان                 1397
# 15   NaN            پتروشیمی خراسان   خراسان                 1396
# 16   NaN            پتروشیمی خراسان   خراسان                 1395
# 17   5.0        پالایش نفت بندرعباس    شبندر                 1399
# 18   NaN        پالایش نفت بندرعباس    شبندر                 1398
# 19   NaN        پالایش نفت بندرعباس    شبندر                 1397
#
#     سال خصوصی شده                                               لینک  \
# 0          1397.0  https://codal.ir/ReportList.aspx?search&Symbol...
# 1             NaN                                                NaN
# 2             NaN                                                NaN
# 3             NaN                                                NaN
# 4          1398.0  https://codal.ir/ReportList.aspx?search&Symbol...
# 5             NaN                                                NaN
# 6             NaN                                                NaN
# 7             NaN                                                NaN
# 8          1398.0  https://codal.ir/ReportList.aspx?search&Symbol...
# 9             NaN                                                NaN
# 10            NaN                                                NaN
# 11            NaN                                                NaN
# 12         1397.0  http://www.tsetmc.com/Loader.aspx?ParTree=1513...
# 13            NaN                                                NaN
# 14            NaN                                                NaN
# 15            NaN                                                NaN
# 16            NaN                                                NaN
# 17         1398.0  https://codal.ir/ReportList.aspx?search&Symbol...
# 18            NaN                                                NaN
# 19            NaN                                                NaN
#
#    Unnamed: 6  سود (زيان) خالص  سود (زيان) عملياتي  مبلغ فروش  ...  \
# 0                     15702755            16632380   69373546  ...
# 1         NaN          5318936             6886233   38377998  ...
# 2         NaN          5268182             6963895   28003445  ...
# 3         NaN           689352             1222929   14597394  ...
# 4                     55677801            57541469  358665256  ...
# 5         NaN         10047996            12782070  258119406  ...
# 6         NaN         16945144            20546523  171496684  ...
# 7         NaN          4301205             7539783   82017675  ...
# 8                     20734008            23349923  145352994  ...
# 9         NaN          1007312             -642794  130179459  ...
# 10        NaN          5366575             6988857   75952695  ...
# 11                     1810038             1319536   39095093  ...
# 12                    14367012            13742321   22157318  ...
# 13                     8750124             8103916   14124456  ...
# 14                     5589480             5264957    9508850  ...
# 15                     2586158             2366300    5593240  ...
# 16                     1729638             1471902    4335528  ...
# 17                   134071751           153055838  894983110  ...
# 18        NaN         26380276            28864651  720189020  ...
# 19        NaN         35087829            41364523  453226514  ...
#
#     جمع بدهی‌ها  بدهی‌های بلند مدت  گردش مقداری فروش    مواد اولیه  \
# 0      20890809            2883819      4.328947e+07  3.795814e+07
# 1      18190925            2271248      2.988361e+07  2.406962e+07
# 2      13689710            2266366      2.161294e+07  1.703455e+07
# 3      10371124            2303645      9.918804e+06  5.430512e+06
# 4      21158209            4085113      3.111737e+08  3.010162e+08
# 5      13739904            3921712      2.379777e+08  2.364754e+08
# 6      17763310            2929904      1.506891e+08  1.551716e+08
# 7      21483173            3153754      7.279559e+07  8.504309e+07
# 8      19682751           10880725      1.279882e+08  1.235425e+08
# 9      21283997            6558614      1.235250e+08  1.229091e+08
# 10     14230458            3264028      6.800701e+07  7.160477e+07
# 11     12857871            1976513      4.652553e+07  5.408103e+07
# 12      4326107            2985431      7.370112e+06  3.594710e+06
# 13      1986937            2032104      5.155530e+06  2.019690e+06
# 14      1118566             500183      3.692535e+06  1.972045e+06
# 15       833353             421115      1.728482e+06  9.061500e+05
# 16       757677             349834      9.846767e+04  5.190883e+05
# 17    106490460            2993933      7.801686e+08  7.591751e+08
# 18     67974597            1465703      6.615541e+08  6.871291e+08
# 19     45235721            1083756      4.087732e+08  4.304634e+08
#
#     هزینه نیروی کار  هزینه استهلاک   هزینه انرژی  آخرین وضعیت سرمایه  \
# 0      2.497102e+06         477286  2.371845e+06             5197831
# 1      1.909611e+06         457147  2.035171e+06             5197831
# 2      1.444634e+06         451232  1.857597e+06             5197831
# 3      1.257579e+06         372571  1.738562e+06             5197831
# 4      9.505070e+05         802925  5.118790e+05             3884211
# 5      5.450860e+05         895573  4.916410e+05             3884211
# 6      4.589650e+05         670945  1.094088e+06             3884211
# 7      4.818860e+05         456668  4.442940e+05             3884211
# 8      1.146748e+06         125909  2.809480e+05             1027549
# 9      7.647090e+05         119294  2.839150e+05             1027549
# 10     5.039660e+05          85041  2.328130e+05             1027549
# 11     4.407310e+05          24829  2.486330e+05             1027549
# 12     9.381350e+05         138475  7.121090e+05             1789912
# 13     6.918950e+05          88232  7.748710e+05             1789912
# 14     5.130850e+05         127965  4.335810e+05             1789912
# 15     4.691800e+05         207592  4.043080e+05             1789912
# 16     3.353383e+05         260623  1.670237e+05             1789912
# 17     3.422396e+06        2155557  0.000000e+00            28688000
# 18     2.197921e+06        1464515  0.000000e+00            28688000
# 19     1.630712e+06         938516  0.000000e+00            28688000
#
#     اورده نقدی  تحقیق و توسعه
# 0      4431909              0
# 1      4431909         793422
# 2      4431909         570924
# 3      4431909              0
# 4      6115789              0
# 5      6115789              0
# 6      6115789              0
# 7      6115789              0
# 8            0              0
# 9            0              0
# 10           0              0
# 11           0              0
# 12           0              0
# 13           0              0
# 14           0              0
# 15           0              0
# 16           0              0
# 17    92993731         102477
# 18    92993731              0
# 19    92993731         113398
#
# [20 rows x 26 columns]

# %%
df_base = pd.DataFrame(df_base)

# %%
list(pd.read_excel('/Users/saeed/Dropbox/Sharif Business Think Thank/خصوصی سازی/شرکت‌های مورد بررسی.xlsx',sheet_name=1).columns)
# Out:
# ['ردیف',
#  'نام شرکت',
#  'نام نماد',
#  'سال آخرین صورت مالی',
#  'سال خصوصی شده',
#  'لینک',
#  'Unnamed: 6',
#  'سود (زيان) خالص',
#  'سود (زيان) عملياتي',
#  'مبلغ فروش',
#  'درصد تغییر سود نسبت به سال قبل',
#  'نرخ تورم',
#  'جمع دارایی\u200cها',
#  'جمع حقوق مالکانه',
#  'جمع پرسنل',
#  'سود (زیان) انباشته',
#  'جمع بدهی\u200cها',
#  'بدهی\u200cهای بلند مدت',
#  'گردش مقداری فروش',
#  'مواد اولیه',
#  'هزینه نیروی کار',
#  'هزینه استهلاک',
#  'هزینه انرژی',
#  'آخرین وضعیت سرمایه',
#  'اورده نقدی',
#  'تحقیق و توسعه']

# %%
df_base.iloc[3,13]
# Out:
# 3500058

# %%
#for i in range(0,len(df_base.columns)-1):
#    for j in range(0,len(df_base.index)):
#        if df_base.iloc[:,i][j]

# %%
names = ['نام شرکت',
 'سود (زيان) خالص',
 'سود عملیاتی نسبت به فروش',
 'سودآوری نسبت به تورم',
 'سود خالص نسبت به مجموع دارایی\u200cها',
 'سود خالص نسبت به حقوق صاحبان سهام',
 'سود خالص نسبت به فروش',
 'سود خالص نسبت به تعداد کارکنان',
 'سود (زیان) انباشته به حقوق صاحبان سهام',
 'نسبت بدهی کل به دارایی کل',
 'نسبت بدهی\u200cهای بلندمدت به حقوق صاحبان سهام',
 'نسبت ارزش افزوده به کل داده با کسر مصارف واسطه',
 'نسبت ارزش افزوده به هزینه کل نیروی کار',
 'نسبت ارزش افزوده به هزینه استفاده از سرمایه',
 'نسبت ارزش افزوده به هزینه انرژی مصرف\u200cشده',
 'نسبت ارزش افزوده به هزینه مواد اولیه',
 "میزان افزایش سرمایه بنگاه از محل آورده نقدی (درصد) نسبت به سرمایه پیشین",
 'میزان افزایش فروش مقداری (تناژ یا تعداد) بنگاه نسبت به زمان واگذاری',
 "نسبت هزینه‌های تحقیق و توسعه به کل هزینه‌ها"
        ]
names
# Out:
# ['نام شرکت',
#  'سود (زيان) خالص',
#  'سود عملیاتی نسبت به فروش',
#  'سودآوری نسبت به تورم',
#  'سود خالص نسبت به مجموع دارایی\u200cها',
#  'سود خالص نسبت به حقوق صاحبان سهام',
#  'سود خالص نسبت به فروش',
#  'سود خالص نسبت به تعداد کارکنان',
#  'سود (زیان) انباشته به حقوق صاحبان سهام',
#  'نسبت بدهی کل به دارایی کل',
#  'نسبت بدهی\u200cهای بلندمدت به حقوق صاحبان سهام',
#  'نسبت ارزش افزوده به کل داده با کسر مصارف واسطه',
#  'نسبت ارزش افزوده به هزینه کل نیروی کار',
#  'نسبت ارزش افزوده به هزینه استفاده از سرمایه',
#  'نسبت ارزش افزوده به هزینه انرژی مصرف\u200cشده',
#  'نسبت ارزش افزوده به هزینه مواد اولیه',
#  'میزان افزایش سرمایه بنگاه از محل آورده نقدی (درصد) نسبت به سرمایه پیشین',
#  'میزان افزایش فروش مقداری (تناژ یا تعداد) بنگاه نسبت به زمان واگذاری',
#  'نسبت هزینه\u200cهای تحقیق و توسعه به کل هزینه\u200cها']

# %%
df = pd.DataFrame(np.nan, index=df_base.index, columns=names)
#df

# %%
from tabulate import tabulate

# %%
df.loc[:, 'نام شرکت'] = df_base.loc[:, 'نام شرکت']
df.loc[:, 'سود (زيان) خالص'] = df_base.loc[:, 'سود (زيان) خالص']

df['سود عملیاتی نسبت به فروش'] = df_base["سود (زيان) عملياتي"] / df_base['مبلغ فروش']
df['سودآوری نسبت به تورم'] = \
((((1 + df_base['درصد تغییر سود نسبت به سال قبل']/100) \
                     / (1 + df_base["نرخ تورم"]/100)
                     )-1)*100).round(2)

df['سود خالص نسبت به مجموع دارایی‌ها'] = df_base['سود (زيان) خالص'] / df_base['جمع دارایی\u200cها']
df['سود خالص نسبت به حقوق صاحبان سهام'] = df_base['سود (زيان) خالص'] / df_base['جمع حقوق مالکانه']
df['سود خالص نسبت به فروش'] = df_base['سود (زيان) خالص'] / df_base['مبلغ فروش']
df['سود خالص نسبت به تعداد کارکنان'] = df_base['سود (زيان) خالص'] / df_base['جمع پرسنل']
df['سود (زیان) انباشته به حقوق صاحبان سهام'] = df_base["سود (زیان) انباشته"] / df_base['جمع حقوق مالکانه']
df['نسبت بدهی کل به دارایی کل'] = df_base['جمع بدهی‌ها'] / df_base['جمع دارایی‌ها']
df['نسبت بدهی‌های بلندمدت به حقوق صاحبان سهام'] = df_base["بدهی‌های بلند مدت"] / df_base['جمع حقوق مالکانه']
# ارزش‌افزوده => df_base['گردش مقداری فروش'] - df_base['مواد اولیه']
df['نسبت ارزش افزوده به کل داده با کسر مصارف واسطه'] = (df_base['گردش مقداری فروش'] - df_base['مواد اولیه']) / (df_base["مواد اولیه"]+df_base["هزینه انرژی"]+df_base["هزینه نیروی کار"]+df_base["هزینه استهلاک"])
df['نسبت ارزش افزوده به هزینه کل نیروی کار'] = (df_base['گردش مقداری فروش'] - df_base['مواد اولیه']) / df_base["هزینه نیروی کار"]
df['نسبت ارزش افزوده به هزینه استفاده از سرمایه'] = (df_base['گردش مقداری فروش'] - df_base['مواد اولیه']) / df_base["هزینه استهلاک"]
df["نسبت ارزش افزوده به هزینه انرژی مصرف‌شده"] = (df_base['گردش مقداری فروش'] - df_base['مواد اولیه']) / df_base["هزینه انرژی"]
df["نسبت ارزش افزوده به هزینه انرژی مصرف‌شده"].replace([np.inf, -np.inf], 0, inplace=True)
df['نسبت ارزش افزوده به هزینه مواد اولیه'] = (df_base['گردش مقداری فروش'] - df_base['مواد اولیه']) / df_base['مواد اولیه']
df['میزان افزایش سرمایه بنگاه از محل آورده نقدی (درصد) نسبت به سرمایه پیشین'] = df_base['اورده نقدی'] / df_base['آخرین وضعیت سرمایه']
df['نسبت هزینه\u200cهای تحقیق و توسعه به کل هزینه\u200cها'] = df_base["تحقیق و توسعه"] / df_base['جمع بدهی\u200cها']
df
# Out:
#                      نام شرکت  سود (زيان) خالص  سود عملیاتی نسبت به فروش  \
# 0   آلومینیوم ایران (ایرالکو)         15702755                  0.239751
# 1   آلومینیوم ایران (ایرالکو)          5318936                  0.179432
# 2   آلومینیوم ایران (ایرالکو)          5268182                  0.248680
# 3   آلومینیوم ایران (ایرالکو)           689352                  0.083777
# 4            پالایش نفت تبریز         55677801                  0.160432
# 5            پالایش نفت تبریز         10047996                  0.049520
# 6            پالایش نفت تبریز         16945144                  0.119807
# 7            پالایش نفت تبریز          4301205                  0.091929
# 8            پالایش نفت شیراز         20734008                  0.160643
# 9            پالایش نفت شیراز          1007312                 -0.004938
# 10           پالایش نفت شیراز          5366575                  0.092016
# 11           پالایش نفت شیراز          1810038                  0.033752
# 12            پتروشیمی خراسان         14367012                  0.620216
# 13            پتروشیمی خراسان          8750124                  0.573751
# 14            پتروشیمی خراسان          5589480                  0.553690
# 15            پتروشیمی خراسان          2586158                  0.423064
# 16            پتروشیمی خراسان          1729638                  0.339498
# 17        پالایش نفت بندرعباس        134071751                  0.171015
# 18        پالایش نفت بندرعباس         26380276                  0.040079
# 19        پالایش نفت بندرعباس         35087829                  0.091267
#
#     سودآوری نسبت به تورم  سود خالص نسبت به مجموع دارایی‌ها  \
# 0                 116.21                          0.317228
# 1                 -25.00                          0.167223
# 2                 486.87                          0.234580
# 3                 177.22                          0.049697
# 4                 306.13                          0.588684
# 5                 -55.95                          0.259986
# 6                 202.54                          0.403978
# 7                  20.61                          0.143922
# 8                1408.61                          0.455487
# 9                 -86.06                          0.037075
# 10                127.68                          0.247566
# 11                 -6.60                          0.121119
# 12                 20.34                          0.632074
# 13                 16.29                          0.646176
# 14                 65.97                          0.638385
# 15                 36.37                          0.480088
# 16                -40.73                          0.377386
# 17                272.49                          0.464130
# 18                -44.15                          0.205569
# 19                118.81                          0.341757
#
#     سود خالص نسبت به حقوق صاحبان سهام  سود خالص نسبت به فروش  \
# 0                            0.555313               0.226351
# 1                            0.390626               0.138593
# 2                            0.600825               0.188126
# 3                            0.196954               0.047224
# 4                            0.758327               0.155236
# 5                            0.403399               0.038928
# 6                            0.700721               0.098807
# 7                            0.511893               0.052442
# 8                            0.802470               0.142646
# 9                            0.171156               0.007738
# 10                           0.720646               0.070657
# 11                           0.867508               0.046298
# 12                           0.780653               0.648409
# 13                           0.757295               0.619502
# 14                           0.731886               0.587819
# 15                           0.567951               0.462372
# 16                           0.452130               0.398945
# 17                           0.735138               0.149804
# 18                           0.437096               0.036630
# 19                           0.610932               0.077418
#
#     سود خالص نسبت به تعداد کارکنان  سود (زیان) انباشته به حقوق صاحبان سهام  \
# 0                      4617.099383                                0.613828
# 1                      1606.929305                                0.580988
# 2                      1991.751229                                0.380696
# 3                       246.549356                               -0.502319
# 4                     68908.169554                                0.801323
# 5                     14820.053097                                0.412881
# 6                     24416.634006                                0.540685
# 7                      6870.934505                                0.283098
# 8                     21620.446298                                0.847915
# 9                      1032.081967                                0.321730
# 10                     5584.365245                                0.504538
# 11                     1927.623003                                0.003260
# 12                    12073.119328                                0.893017
# 13                     7219.574257                                0.829598
# 14                    13340.047733                                0.742192
# 15                     6172.214797                                0.567605
# 16                     4050.674473                                0.485326
# 17                    36422.643575                                0.757529
# 18                    16244.012315                                0.270114
# 19                    26401.677201                                0.393764
#
#     نسبت بدهی کل به دارایی کل  نسبت بدهی‌های بلندمدت به حقوق صاحبان سهام  \
# 0                    0.422037                                   0.101983
# 1                    0.571909                                   0.166802
# 2                    0.609571                                   0.258474
# 3                    0.747674                                   0.658173
# 4                    0.223707                                   0.055639
# 5                    0.355512                                   0.157446
# 6                    0.423483                                   0.121158
# 7                    0.718844                                   0.375333
# 8                    0.432393                                   0.421117
# 9                    0.783383                                   1.114400
# 10                   0.656467                                   0.438307
# 11                   0.860383                                   0.947295
# 12                   0.190326                                   0.162218
# 13                   0.146731                                   0.175872
# 14                   0.127754                                   0.065494
# 15                   0.154702                                   0.092482
# 16                   0.165316                                   0.091447
# 17                   0.368649                                   0.016416
# 18                   0.529694                                   0.024285
# 19                   0.440598                                   0.018870
#
#     نسبت ارزش افزوده به کل داده با کسر مصارف واسطه  \
# 0                                         0.123113
# 1                                         0.204203
# 2                                         0.220242
# 3                                         0.510078
# 4                                         0.033492
# 5                                         0.006301
# 6                                        -0.028479
# 7                                        -0.141711
# 8                                         0.035538
# 9                                         0.004964
# 10                                       -0.049675
# 11                                       -0.137886
# 12                                        0.701301
# 13                                        0.877235
# 14                                        0.564711
# 15                                        0.413808
# 16                                       -0.328078
# 17                                        0.027451
# 18                                       -0.037023
# 19                                       -0.050089
#
#     نسبت ارزش افزوده به هزینه کل نیروی کار  \
# 0                                 2.135007
# 1                                 3.044593
# 2                                 3.169237
# 3                                 3.568994
# 4                                10.686319
# 5                                 2.756051
# 6                                -9.766507
# 7                               -25.415760
# 8                                 3.876813
# 9                                 0.805505
# 10                               -7.138886
# 11                              -17.143111
# 12                                4.024370
# 13                                4.532248
# 14                                3.353226
# 15                                1.752700
# 16                               -1.254317
# 17                                6.134138
# 18                              -11.635986
# 19                              -13.301064
#
#     نسبت ارزش افزوده به هزینه استفاده از سرمایه  \
# 0                                     11.170095
# 1                                     12.717983
# 2                                     10.146415
# 3                                     12.046810
# 4                                     12.650523
# 5                                      1.677457
# 6                                     -6.680853
# 7                                    -26.819263
# 8                                     35.309049
# 9                                      5.163520
# 10                                   -42.306135
# 11                                  -304.301435
# 12                                    27.264142
# 13                                    35.540847
# 14                                    13.445004
# 15                                     3.961289
# 16                                    -1.613905
# 17                                     9.739222
# 18                                   -17.463105
# 19                                   -23.111172
#
#     نسبت ارزش افزوده به هزینه انرژی مصرف‌شده  \
# 0                                   2.247756
# 1                                   2.856757
# 2                                   2.464683
# 3                                   2.581612
# 4                                  19.843402
# 5                                   3.055654
# 6                                  -4.097006
# 7                                 -27.566204
# 8                                  15.824021
# 9                                   2.169582
# 10                                -15.453415
# 11                                -30.388164
# 12                                  5.301719
# 13                                  4.046919
# 14                                  3.968094
# 15                                  2.033925
# 16                                 -2.518330
# 17                                  0.000000
# 18                                  0.000000
# 19                                  0.000000
#
#     نسبت ارزش افزوده به هزینه مواد اولیه  \
# 0                               0.140453
# 1                               0.241549
# 2                               0.268771
# 3                               0.826495
# 4                               0.033744
# 5                               0.006353
# 6                              -0.028887
# 7                              -0.144015
# 8                               0.035985
# 9                               0.005012
# 10                             -0.050245
# 11                             -0.139707
# 12                              1.050266
# 13                              1.552634
# 14                              0.872440
# 15                              0.907501
# 16                             -0.810307
# 17                              0.027653
# 18                             -0.037220
# 19                             -0.050388
#
#     میزان افزایش سرمایه بنگاه از محل آورده نقدی (درصد) نسبت به سرمایه پیشین  \
# 0                                            0.852646
# 1                                            0.852646
# 2                                            0.852646
# 3                                            0.852646
# 4                                            1.574525
# 5                                            1.574525
# 6                                            1.574525
# 7                                            1.574525
# 8                                            0.000000
# 9                                            0.000000
# 10                                           0.000000
# 11                                           0.000000
# 12                                           0.000000
# 13                                           0.000000
# 14                                           0.000000
# 15                                           0.000000
# 16                                           0.000000
# 17                                           3.241555
# 18                                           3.241555
# 19                                           3.241555
#
#     میزان افزایش فروش مقداری (تناژ یا تعداد) بنگاه نسبت به زمان واگذاری  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#     نسبت هزینه‌های تحقیق و توسعه به کل هزینه‌ها
# 0                                      0.000000
# 1                                      0.043616
# 2                                      0.041705
# 3                                      0.000000
# 4                                      0.000000
# 5                                      0.000000
# 6                                      0.000000
# 7                                      0.000000
# 8                                      0.000000
# 9                                      0.000000
# 10                                     0.000000
# 11                                     0.000000
# 12                                     0.000000
# 13                                     0.000000
# 14                                     0.000000
# 15                                     0.000000
# 16                                     0.000000
# 17                                     0.000962
# 18                                     0.000000
# 19                                     0.002507

# %%
df = df.round(3)

# %%
# def color_negative_red(val):
#     """
#     Takes a scalar and returns a string with
#     the css property `'color: red'` for negative
#     strings, black otherwise.
#     """
#     color = 'red' if val < 0 else 'black'
#     return 'color: % s' % color

# df.iloc[:,1:].style.applymap(color_negative_red)
